# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarGuti17/Ejercicio-Curso/blob/main/Ejercicios_de_GroupBy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar pandas

import pandas as pd

# %%
path = '/content/sample_data/Ejercicios de GroupBy.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    7  07/24/05  00:00:00  0
# 0  9  07/24/05  00:00:00  0
# 1  7  07/24/05  00:30:00  1
# 2  9  07/24/05  00:30:00  0
# 3  7  07/24/05  01:00:00  0
# 4  9  07/24/05  01:00:00  0

# %%
df.columns = ['Título','Autor','Género','Valoración']
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-42a7405caa46> in <cell line: 2>()
#       1 # Remove unnecessary columns
# ----> 2 df = df.drop(columns=['Unnamed: 0', 'PassengerId', 'Name'])
#       3 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
# ...
