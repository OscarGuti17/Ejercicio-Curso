# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarGuti17/Ejercicio-Curso/blob/main/Presentaci%C3%B3n_Ejecutivos_RRHH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Load the Data
df = pd.read_csv('/content/sample_data/employee_attrition.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    588 non-null    object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Limpiar Columnas

# %%
(df['Age'].value_counts())
# Out:
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64

# %%
(df['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
(df['BusinessTravel'].value_counts())
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
(df['DailyRate'].value_counts())
# Out:
# DailyRate
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: count, Length: 886, dtype: int64

# %%
(df['Department'].value_counts())
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
(df['DistanceFromHome'].value_counts())
# Out:
# DistanceFromHome
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: count, dtype: int64

# %%
(df['Education'].value_counts())
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64

# %%
(df['EducationField'].value_counts())
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
(df['EmployeeCount'].value_counts())
# Out:
# EmployeeCount
# 1    1470
# Name: count, dtype: int64

# %%
(df['EmployeeNumber'].value_counts())
# Out:
# EmployeeNumber
# 1       1
# 1391    1
# 1389    1
# 1387    1
# 1383    1
#        ..
# 659     1
# 657     1
# 656     1
# 655     1
# 2068    1
# Name: count, Length: 1470, dtype: int64

# %%
(df['EnvironmentSatisfaction'].value_counts())
# Out:
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64

# %%
(df['Gender'].value_counts())
# Out:
# Gender
# Female    588
# Name: count, dtype: int64

# %%
(df['HourlyRate'].value_counts())
# Out:
# HourlyRate
# 66    29
# 98    28
# 42    28
# 48    28
# 84    28
#       ..
# 31    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: count, Length: 71, dtype: int64

# %%
(df['JobInvolvement'].value_counts())
# Out:
# JobInvolvement
# 3    868
# 2    375
# 4    144
# 1     83
# Name: count, dtype: int64

# %%
(df['JobLevel'].value_counts())
# Out:
# JobLevel
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: count, dtype: int64

# %%
(df['JobSatisfaction'].value_counts())
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64

# %%
(df['MaritalStatus'].value_counts())
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
(df['MonthlyIncome'].value_counts())
# Out:
# MonthlyIncome
# 2342     4
# 6142     3
# 2741     3
# 2559     3
# 2610     3
#         ..
# 7104     1
# 2773     1
# 19513    1
# 3447     1
# 4404     1
# Name: count, Length: 1349, dtype: int64

# %%
(df['MonthlyRate'].value_counts())
# Out:
# MonthlyRate
# 4223     3
# 9150     3
# 9558     2
# 12858    2
# 22074    2
#         ..
# 14561    1
# 2671     1
# 5718     1
# 11757    1
# 10228    1
# Name: count, Length: 1427, dtype: int64

# %%
(df['NumCompaniesWorked'].value_counts())
# Out:
# NumCompaniesWorked
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: count, dtype: int64

# %%
(df['Over18'].value_counts())
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
(df['OverTime'].value_counts())
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
(df['PercentSalaryHike'].value_counts())
# Out:
# PercentSalaryHike
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: count, dtype: int64

# %%
(df['PerformanceRating'].value_counts())
# Out:
# PerformanceRating
# 3    1244
# 4     226
# Name: count, dtype: int64

# %%
(df['RelationshipSatisfaction'].value_counts())
# Out:
# RelationshipSatisfaction
# 3    459
# 4    432
# 2    303
# 1    276
# Name: count, dtype: int64

# %%
(df['StandardHours'].value_counts())
# Out:
# StandardHours
# 80    1470
# Name: count, dtype: int64

# %%
(df['StockOptionLevel'].value_counts())
# Out:
# StockOptionLevel
# 0    631
# 1    596
# 2    158
# 3     85
# Name: count, dtype: int64

# %%
(df['TotalWorkingYears'].value_counts())
# Out:
# TotalWorkingYears
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: count, dtype: int64

# %%
(df['TrainingTimesLastYear'].value_counts())
# Out:
# TrainingTimesLastYear
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: count, dtype: int64

# %%
(df['WorkLifeBalance'].value_counts())
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
(df['YearsAtCompany'].value_counts())
# Out:
# YearsAtCompany
# 5     195
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 5!      1
# 34      1
# 30      1
# Name: count, dtype: int64

# %%
# Corregir "YearsAtCompany" 5! a 5
df['YearsAtCompany'].replace({"5!":"5"}, inplace=True)
df['YearsAtCompany'].value_counts()
# Out:
# YearsAtCompany
# 5     196
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 34      1
# 30      1
# Name: count, dtype: int64

# %%
(df['YearsInCurrentRole'].value_counts())
# Out:
# YearsInCurrentRole
# 2     372
# 0     244
# 7     222
# 3     135
# 4     104
# 8      89
# 9      67
# 1      57
# 6      37
# 5      36
# 10     29
# 11     22
# 13     14
# 14     11
# 12     10
# 15      8
# 16      7
# 17      4
# 18      2
# Name: count, dtype: int64

# %%
(df['YearsSinceLastPromotion'].value_counts())
# Out:
# YearsSinceLastPromotion
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: count, dtype: int64

# %%
(df['YearsWithCurrManager'].value_counts())
# Out:
# YearsWithCurrManager
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: count, dtype: int64

# %%
# Mostrar valores columnas con numeros Faltantes
print(df.isna().sum())
# Out:
# Age                           0
# Attrition                     0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                      882
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# ...

# %%
# Reemplazar datos perdidos "Gender" Vacios = Male
# asumiendo que todo lo que es vacio es Male
df['Gender'].fillna('Male', inplace=True)

# %%
# Mostrar valores columnas con numeros Faltantes
print(df.isna().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Cambiar ‘EmployeeNumber’ debe ser el índice del marco de datos
df.set_index('EmployeeNumber', inplace=True)

# %%
# Cambio La columna ‘EmployeeNumber’
df
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %% [markdown]
# # PARTE 2 EXAMEN

# %%
# Analisís de tendencias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1470 entries, 1 to 2068
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %%
from matplotlib import pyplot as plt
df['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Se observa que la frecuencia de viajes estan relacionadas en promedio de edad de 30 a 40, y en menor relacion los menores y mayores.

# %%
from matplotlib import pyplot as plt
df['DistanceFromHome'].plot(kind='hist', bins=20, title='DistanceFromHome')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Se Observa que la relacion distancia Frecuencia, es mayormente relacionada con menor distancia mas frecuencia, podemos decir que la distancia influye fuertemente en los trabajadores.

# %%
from matplotlib import pyplot as plt
df['Education'].plot(kind='hist', bins=20, title='Education')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Podemos deducir que la educacion en promedio bordea los 3 años, y en menos 1 y 5, esto indica que el personal necesita capacitacion y experiencia.
